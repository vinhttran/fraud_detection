# %% [markdown]
# # Fraud EDA
# - null values
# - column names
# - col heatmap
# - clean df

# %%
import os

# %%
import pandas as pd
import pandas_profiling as pps
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 500)
df = pd.read_json('data/data.json')
# pd.set_option('display.max_colwidth', -1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
fig,ax = plt.subplots(figsize=(30,20))
sns.heatmap(df.corr(),annot=True)
ax.set_xticklabels(df.columns,fontsize=20)
ax.set_yticklabels(df.columns,fontsize=20)
plt.show()

# %%
df0 = pd.DataFrame([{'body_length': 5004,
                     'channels': 4,
                     'country': 'US',
                     'currency': 'USD',
                     'delivery_method': 0.0,
                     'description': '<div style="text-align: center;">\r\n<p style="margin: 0px;\
                         text-align: center; font-size: 32px; font-family: Impact; color: #091980;\
                         "><span style="letter-spacing: 0px; font-size: medium;"><img  alt="" width\
                         ="497" height="665" /></span></p>\r\n<p style="margin: 0px; text-align:\
                         center; font-size: 32px; font-family: Impact; color: #091980;"><span style=\
                         "letter-spacing: 0px; font-size: medium;">The Exchange Club of West Hartford\
                         </span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size:\
                         18px; font-family: Impact;"><em><span style="letter-spacing: 0px; font-size: \
                         small; font-family: verdana,geneva;">invites you to join us for</span></em></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 32px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: medium;">7th ANNUAL WINE TASTING</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 15px; font-family: Tahoma;"><span style="letter-spacing: 0px; font-size: small;">&nbsp;A night full of community and friends - with wines to taste, micro brews to sample, a Martini Bar, heavy hors d&rsquo;oeurvres, music, &amp; dancing.</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 24px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">TO BENEFIT</span></p>\r\n</div>\r\n<div>\r\n<p style="text-align: center;"><span style="color: #000080; font-family: impact, chicago; font-size: x-large;"><img  alt="Unified Theater" width="208" height="69" /></span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 24px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">&amp; the Exchange Club of West Hartford&nbsp;</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-family: Verdana; min-height: 12px;">&nbsp;</p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">HEAVY HOR D&rsquo;OEUVRES &amp; WINE TASTING</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: small;">6:30PM ‐ 8:30PM</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">DANCING &amp; ENTERTAINMENT</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: small;">8:30 ‐ 11:30PM</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 18px; font-family: Impact; color: #091980; text-align: center;"><em><strong><span style="font-family: verdana,geneva; font-size: small; color: #000000;">Tickets can be purchased online here, from any Exchange Club member, or from our generous supporters at Wine Cellars&nbsp;4 (68 Farmington Ave. Farmington, just past the reservoir).</span></strong></em></p>\r\n<p style="margin: 0px 0px 10px; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">About the Exchange Club of West Hartford</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 13px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: x-small;">The Exchange Club of West Hartford works to make West Hartford a better place to live through programs of service, Americanism, and Youth Activities. You may know us as flag wavers at the Memorial Day Parade, course guides during the Mitten Run, sponsors of the West Hartford Police &amp; Firefighters Service Awards, or through the scholarships we provide to Hall and Conard graduates each year.</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">About Unified Theater</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 13px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: x-small;">Unified Theater (<a href="http://www.unifiedtheater.org"><span style="letter-spacing: 0px; color: #000000;">www.unifiedtheater.org</span></a>) creates school-base, student-led performing arts groups that bring together young people of all abilities, interests, and backgrounds.&nbsp; Since it\'s founding in 2002 by a Conard student (and Exchange Club scholarship recipient!), Unified Theater has served over 4,000 students of all abilities and touched over 10,000 audience members.</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 13px; font-family: Verdana; text-align: center;"><span style="color: #000080; font-family: impact,chicago; font-size: small;">The Exchange Club Wine Tasting has sold out the past two years - get your tickets today!</span></p>\r\n</div>', 'email_domain': 'gmail.com', 'event_created': 1355244741, 'event_end': 1359876600, 'event_published': 1355245319.0, 'event_start': 1359858600, 'fb_published': 0, 'has_analytics': 0, 'has_header': None, 'has_logo': 1, 'listed': 'y', 'name': '7th Annual West Hartford Exchange Club Wine Tasting', 'name_length': 51, 'object_id': 5008170, 'org_desc': '', 'org_facebook': 24.0, 'org_name': 'Exchange Club of West Hartford', 'org_twitter': 0.0, 'payee_name': 'West Hartford Exchange Club', 'payout_type': 'CHECK', 'previous_payouts': [], 'sale_duration': 53.0, 'show_map': 1, 'ticket_types': [{'event_id': 5008170, 'cost': 50.0, 'availability': 1, 'quantity_total': 200}, {'event_id': 5008170, 'cost': 0.0, 'availability': 1, 'quantity_total': 0}], 'user_age': 0, 'user_created': 1355244739, 'user_type': 1, 'venue_address': '50 S Main St', 'venue_country': 'US', 'venue_latitude': 41.7593991, 'venue_longitude': -72.7423451, 'venue_name': 'The West Hartford Meeting & Conference Center (FREE PARKING)', 'venue_state': 'CT', 'sequence_number': 1965}])

# %% [markdown]
# ##### Columns with null values

# %%
df0.columns[df0.isna().sum()==1]
# Out:
# Index(['has_header'], dtype='object')

# %%
df0.columns
# Out:
# Index(['body_length', 'channels', 'country', 'currency', 'delivery_method',
#        'description', 'email_domain', 'event_created', 'event_end',
#        'event_published', 'event_start', 'fb_published', 'has_analytics',
#        'has_header', 'has_logo', 'listed', 'name', 'name_length', 'object_id',
#        'org_desc', 'org_facebook', 'org_name', 'org_twitter', 'payee_name',
#        'payout_type', 'previous_payouts', 'sale_duration', 'sequence_number',
#        'show_map', 'ticket_types', 'user_age', 'user_created', 'user_type',
#        'venue_address', 'venue_country', 'venue_latitude', 'venue_longitude',
#        'venue_name', 'venue_state'],
#       dtype='object')

# %% [markdown]
# ## API generated data

# %%
import requests
url = 'http://galvanize-case-study-on-fraud.herokuapp.com/data_point'

response = requests.get(url)
raw_data = response.json()

# %%
data = raw_data.copy()
data['description'] = 0
data['previous_payouts'] = len(data['previous_payouts'])
df = pd.DataFrame(data)

# %%
df.ticket_types[0]
# Out:
# {'availability': 1,
#  'cost': 7.47,
#  'event_id': 7598925,
#  'quantity_sold': 9,
#  'quantity_total': 40}
