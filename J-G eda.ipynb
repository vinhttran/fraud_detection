# %%
import pandas as pd
import pandas_profiling as pp
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_json('data/data.json')

# %%
pd.set_option('display.max_colwidth', -1)
df['name']
# Out:
# 0        99 HOUR "NO SLEEP" SUPER BOWL CELEBRITY WEEKEND GRAND FINALE
# 1        Winthrop RUF Winter Getaway
# 2        DRDP (2010) Teacher Training
# 3        ITTA Affiliation 2013
# 4        Self Defense for Writers and Filmmakers: For Artists and Attorneys
# 5        Bluegrass Stallions vs Rochester Razorsharks
# 6        Fridays at Four Frederick 2011-02-11
# 7        When Jekyll Met Hyde (1960s)
# 8        A Sweetheart Affair
# 9        When Jekyll Met Hyde (1950s)
# 10       Understanding and Supporting Families with Domestic Violence Issues
# 11       Wild Seafood: San Francisco Fishing Tour Feb 13
# 12       LinkedIn Profiles Plus (BAC) – Ft. Worth, TX, April 12, 2011
# 13       CSPA Presenting Guy Kawasaki Enchantment - The Art of Changing Hearts, Minds and Actions
# 14       Simply Stylist Seminar
# 15       Race to Nowhere, Candlewood Middle School, Dix Hills, NY
# 16       Race to Nowhere, Endicott College, hosted by ConSone Academy
# 17       Martin England & the Recontructed Benefit Show
# 18       IPCybercrime Boot Camp - Vancouver 2011
# 19       Mélange Fashion Show 2011
# 20       The European Independent Film Festival
# 21       Jim Riley Drum Lesson 10:00 a.m.
# 22       Business Man's Retreat
# 23       Cultures, Strategic Markets & Fair Housing - Morning Session
# 24       A Night with Kip Knight: Social Media Metrics\r\nWhat? So what? Now what?\r\n\r\n
# 25       Horsemanship Merit Badge - Class 2011-04-16-Saturday Late Afternoon
# 26       Series 2 of CSI Seminars for Transformation Expo
# 27       Chicago Forward: A Conversation with Chicago's Mayor Elect
# 28       Botox & Dermal Fillers Hands on Training - Level One Houston, TX June 24 -25 2011 - Sign up before July 1 - save $500 - Pay only $2997
# 29       DISTRIKT Cinco de Mayo L.A.!
#                      ...
# 14307    ATD Fix It In Post 020113
# 14308    Charlotte Night of Worship & Ministry
# 14309    BWEC 2013 (Sterling Payments)
# 14310    Considering or Committed to Making Positive Change???
# 14311    Becoming a Stretcher Bearer
# 14312    2013 Winfield Criterium Weekend
# 14313    Kingdom Rave 3D
# 14314    16-hour PIECES Education Program - Bancroft Feb 13 & 27, 2013
# 14315    Eiki and Kris - Teachers workshop
# 14316    SINGLES AND FAMILY DINNER FUN NIGHT
# 14317    GOD DES AND SHE LIVE IN SAN DIEGO @ RUBY ROOM
# 14318    The NYC Speed Dating Expose
# 14319    The Anatomy of Peace 8-Week Course by Phone
# 14320    Three Witnesses
# 14321    The Fetch Sydney Dinner: a conversation on Content Strategy
# 14322    Motorcycle Show & Swap Meet
# 14323    Introduction to Computer Science - Problem Solving for Fun
# 14324    LEGION FETISH EVENTS PRESENTS "KINK ON THE RIVER"
# 14325    Inner City Children’s Advocacy Center  Dinner
# 14326    Sandie Byrne Medium, Ennis, April 26th 2013
# 14327    5th Annual Anti-Racist Pedagogy Across the Curriculum Workshop
# 14328    Twitter Prospect Psychology - How To Identify & Connect With Customers Who Are Primed And Ready To Buy
# 14329    Twitter Prospect Psychology - How To Identify & Connect With Customers Who Are Primed And Ready To Buy
# 14330    "Evening of Sheer Elegance" Fashion Show
# 14331    IntelliPlex Advanced Topics Workshop June 3
# 14332    President's Day Celebration
# 14333    ARCS Foundation 2013 Scientist of the Year
# 14334    TIFFANTASY ENTERTAINMENT PRESENTS: Ruff and Ready: Fucking Problems
# 14335    Valentines Day Dinner & Comedy Show At Salsa Con Fuego
# 14336    thaimassage
# Name: name, Length: 14337, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null int64
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# name                  14337 non-null object
# name_length           14337 non-null int64
# num_order             14337 non-null int64
# num_payouts           14337 non-null int64
# object_id             14337 non-null int64
# org_desc              14337 non-null object
# org_facebook          14278 non-null float64
# org_name              14337 non-null object
# org_twitter           14278 non-null float64
# payee_name            14337 non-null object
# payout_type           14337 non-null object
# previous_payouts      14337 non-null object
# sale_duration         14182 non-null float64
# sale_duration2        14337 non-null int64
# show_map              14337 non-null int64
# ticket_types          14337 non-null object
# user_age              14337 non-null int64
# user_created          14337 non-null int64
# user_type             14337 non-null int64
# venue_address         14337 non-null object
# venue_country         13261 non-null object
# venue_latitude        13261 non-null float64
# venue_longitude       13261 non-null float64
# venue_name            13261 non-null object
# venue_state           13261 non-null object
# dtypes: float64(9), int64(18), object(17)
# memory usage: 4.8+ MB

# %%
df.columns
# Out:
# Index(['acct_type', 'approx_payout_date', 'body_length', 'channels', 'country',
#        'currency', 'delivery_method', 'description', 'email_domain',
#        'event_created', 'event_end', 'event_published', 'event_start',
#        'fb_published', 'gts', 'has_analytics', 'has_header', 'has_logo',
#        'listed', 'name', 'name_length', 'num_order', 'num_payouts',
#        'object_id', 'org_desc', 'org_facebook', 'org_name', 'org_twitter',
#        'payee_name', 'payout_type', 'previous_payouts', 'sale_duration',
#        'sale_duration2', 'show_map', 'ticket_types', 'user_age',
#        'user_created', 'user_type', 'venue_address', 'venue_country',
#        'venue_latitude', 'venue_longitude', 'venue_name', 'venue_state'],
#       dtype='object')

# %%
pd.set_option('display.max_colwidth', 40)
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method                              description  \
# 0      USD              0.0  <p><a href="http://s432.photobucket....
# 1      USD              1.0  <p>Join us for a quick, one-night, c...
# 2      USD              1.0  <h3><span class="subcategory"><stron...
# 3      EUR              1.0  <p style="margin-bottom: 1.3em; padd...
# 4      USD              0.0  <p>Writers and filmmakers need to un...
#
#                  email_domain  event_created   event_end  event_published  \
# 0                   gmail.com     1262739706  1265630400     1.263110e+09
# 1                     ruf.org     1293832670  1296288000     1.293833e+09
# 2              pvsd.k12.ca.us     1291090956  1295740800     1.291092e+09
# 3        irishtabletennis.com     1360681570  1388534400     1.360683e+09
# 4  artsandbusinesscouncil.org     1291994666  1297468800     1.291995e+09
#
#    event_start  fb_published      gts  has_analytics  has_header  has_logo  \
# 0   1265594400             0     0.00              0         1.0         0
# 1   1296255600             0   868.02              0         0.0         1
# 2   1295713800             0  3500.00              0         NaN         0
# 3   1360702800             0  1167.35              0         0.0         1
# 4   1297440000             1  2313.15              0         0.0         0
#
#   listed                                     name  name_length  num_order  \
# 0      y  99 HOUR "NO SLEEP" SUPER BOWL CELEBR...           60          0
# 1      n              Winthrop RUF Winter Getaway           27         23
# 2      y             DRDP (2010) Teacher Training           28         19
# 3      y                    ITTA Affiliation 2013           21         39
# 4      y  Self Defense for Writers and Filmmak...           66         30
#
#    num_payouts  object_id                                 org_desc  \
# 0            0     527017
# 1            1     786878  <p>Since 1987, RUF has ministered to...
# 2            4     787337  <p><a href="http://www.desiredresult...
# 3           16     885645
# 4            0    1114349  <p><font face="Arial"><font size="2"...
#
#    org_facebook                                 org_name  org_twitter  \
# 0           0.0    Party Starz Ent & Diverse Int'l Group          0.0
# 1           0.0               RUF at Winthrop University         12.0
# 2           0.0  University Preparation School in col...          0.0
# 3           0.0                                                   0.0
# 4           0.0  Arts & Business Council of Greater B...          0.0
#
#                                 payee_name payout_type  \
# 0
# 1                                      RUF       CHECK
# 2            University Preparation School       CHECK
# 3                                                  ACH
# 4  Arts and Business Council or Greater...       CHECK
#
#                           previous_payouts  sale_duration  sale_duration2  \
# 0                                       []           29.0              33
# 1  [{'name': 'RUF', 'created': '2010-10...           28.0              28
# 2  [{'name': 'Danielle Severn', 'create...           54.0              54
# 3  [{'name': '', 'created': '2010-11-09...            0.0               0
# 4  [{'name': 'Arts and Business Council...           63.0              63
#
#    show_map                             ticket_types  user_age  user_created  \
# 0         1  [{'event_id': 527017, 'cost': 25.0, ...        36    1259613950
# 1         0  [{'event_id': 786878, 'cost': 35.0, ...       149    1280942776
# 2         0  [{'event_id': 787337, 'cost': 93.51,...       214    1272559388
# 3         0  [{'event_id': 885645, 'cost': 25.0, ...       889    1283870102
# 4         0  [{'event_id': 1114349, 'cost': 150.0...        35    1288984065
#
#    user_type                 venue_address venue_country  venue_latitude  \
# 0          1         717 Washington Avenue            US       25.777471
# 1          3                                          US       32.776566
# 2          3  10100 Pioneer Blvd Suite 100            US       33.944201
# 3          3                                        None             NaN
# 4          3        One Marina Park Drive             US       42.353848
#
#    venue_longitude                              venue_name venue_state
# 0       -80.133433             INK Nightclub - South Beach          FL
# 1       -79.930922                 The Charleston, SC area          SC
# 2      -118.080419  Los Angeles County Office of Education          CA
# 3              NaN                                    None        None
# 4       -71.044276                       Fish & Richardson          MA

# %%
pp.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>44 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>14337 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>1.8% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>4.8 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>352.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>18 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>2 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_body_length"><code>body_length</code></a> has 829 / 5.8% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_channels"><code>channels</code></a> has 2941 / 20.5% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_country"><code>country</code></a> has a high cardinality: 73 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_delivery_method"><code>delivery_method</code></a> has 8520 / 59.4% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_description"><code>description</code></a> has a high cardinality: 13095 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_email_domain"><code>email_domain</code></a> has a high cardinality: 5772 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_event_created"><code>event_created</code></a> is highly correlated with <a href="#pp_var_approx_payout_date"><code>approx_payout_date</code></a> (ρ = 0.97143) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_event_end"><code>event_end</code></a> is highly correlated with <a href="#pp_var_event_created

# %%
test = pd.DataFrame([{'A': 1, 'B':2}, {'A': 3, 'B':4}])

# %%
test
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.20.1.

# %%
df0 = pd.DataFrame([{'body_length': 5004, 'channels': 4, 'country': 'US', 'currency': 'USD', 'delivery_method': 0.0, 'description': '<div style="text-align: center;">\r\n<p style="margin: 0px; text-align: center; font-size: 32px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: medium;"><img  alt="" width="497" height="665" /></span></p>\r\n<p style="margin: 0px; text-align: center; font-size: 32px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: medium;">The Exchange Club of West Hartford</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Impact;"><em><span style="letter-spacing: 0px; font-size: small; font-family: verdana,geneva;">invites you to join us for</span></em></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 32px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: medium;">7th ANNUAL WINE TASTING</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 15px; font-family: Tahoma;"><span style="letter-spacing: 0px; font-size: small;">&nbsp;A night full of community and friends - with wines to taste, micro brews to sample, a Martini Bar, heavy hors d&rsquo;oeurvres, music, &amp; dancing.</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 24px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">TO BENEFIT</span></p>\r\n</div>\r\n<div>\r\n<p style="text-align: center;"><span style="color: #000080; font-family: impact, chicago; font-size: x-large;"><img  alt="Unified Theater" width="208" height="69" /></span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 24px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">&amp; the Exchange Club of West Hartford&nbsp;</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-family: Verdana; min-height: 12px;">&nbsp;</p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">HEAVY HOR D&rsquo;OEUVRES &amp; WINE TASTING</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: small;">6:30PM ‐ 8:30PM</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">DANCING &amp; ENTERTAINMENT</span></p>\r\n<p style="margin: 0px 0px 10px; text-align: center; font-size: 18px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: small;">8:30 ‐ 11:30PM</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 18px; font-family: Impact; color: #091980; text-align: center;"><em><strong><span style="font-family: verdana,geneva; font-size: small; color: #000000;">Tickets can be purchased online here, from any Exchange Club member, or from our generous supporters at Wine Cellars&nbsp;4 (68 Farmington Ave. Farmington, just past the reservoir).</span></strong></em></p>\r\n<p style="margin: 0px 0px 10px; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">About the Exchange Club of West Hartford</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 13px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: x-small;">The Exchange Club of West Hartford works to make West Hartford a better place to live through programs of service, Americanism, and Youth Activities. You may know us as flag wavers at the Memorial Day Parade, course guides during the Mitten Run, sponsors of the West Hartford Police &amp; Firefighters Service Awards, or through the scholarships we provide to Hall and Conard graduates each year.</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 18px; font-family: Impact; color: #091980;"><span style="letter-spacing: 0px; font-size: small;">About Unified Theater</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 13px; font-family: Verdana;"><span style="letter-spacing: 0px; font-size: x-small;">Unified Theater (<a href="http://www.unifiedtheater.org"><span style="letter-spacing: 0px; color: #000000;">www.unifiedtheater.org</span></a>) creates school-base, student-led performing arts groups that bring together young people of all abilities, interests, and backgrounds.&nbsp; Since it\'s founding in 2002 by a Conard student (and Exchange Club scholarship recipient!), Unified Theater has served over 4,000 students of all abilities and touched over 10,000 audience members.</span></p>\r\n<p style="margin: 0px 0px 10px; font-size: 13px; font-family: Verdana; text-align: center;"><span style="color: #000080; font-family: impact,chicago; font-size: small;">The Exchange Club Wine Tasting has sold out the past two years - get your tickets today!</span></p>\r\n</div>', 'email_domain': 'gmail.com', 'event_created': 1355244741, 'event_end': 1359876600, 'event_published': 1355245319.0, 'event_start': 1359858600, 'fb_published': 0, 'has_analytics': 0, 'has_header': None, 'has_logo': 1, 'listed': 'y', 'name': '7th Annual West Hartford Exchange Club Wine Tasting', 'name_length': 51, 'object_id': 5008170, 'org_desc': '', 'org_facebook': 24.0, 'org_name': 'Exchange Club of West Hartford', 'org_twitter': 0.0, 'payee_name': 'West Hartford Exchange Club', 'payout_type': 'CHECK', 'previous_payouts': [], 'sale_duration': 53.0, 'show_map': 1, 'ticket_types': [{'event_id': 5008170, 'cost': 50.0, 'availability': 1, 'quantity_total': 200}, {'event_id': 5008170, 'cost': 0.0, 'availability': 1, 'quantity_total': 0}], 'user_age': 0, 'user_created': 1355244739, 'user_type': 1, 'venue_address': '50 S Main St', 'venue_country': 'US', 'venue_latitude': 41.7593991, 'venue_longitude': -72.7423451, 'venue_name': 'The West Hartford Meeting & Conference Center (FREE PARKING)', 'venue_state': 'CT', 'sequence_number': 1965}])

# %%
df0
# Out:
#    body_length  channels country currency  delivery_method  \
# 0         5004         4      US      USD              0.0
#
#                                description email_domain  event_created  \
# 0  <div style="text-align: center;">\r\...    gmail.com     1355244741
#
#     event_end  event_published  event_start  fb_published  has_analytics  \
# 0  1359876600     1.355245e+09   1359858600             0              0
#
#   has_header  has_logo listed                                     name  \
# 0       None         1      y  7th Annual West Hartford Exchange Cl...
#
#    name_length  object_id org_desc  org_facebook  \
# 0           51    5008170                   24.0
#
#                          org_name  org_twitter                   payee_name  \
# 0  Exchange Club of West Hartford          0.0  West Hartford Exchange Club
#
#   payout_type previous_payouts  sale_duration  sequence_number  show_map  \
# 0       CHECK               []           53.0             1965         1
#
#                               ticket_types  user_age  user_created  user_type  \
# 0  [{'event_id': 5008170, 'cost': 50.0,...         0    1355244739          1
#
#   venue_address venue_country  venue_latitude  venue_longitude  \
# 0  50 S Main St            US       41.759399       -72.742345
#
#                                 venue_name venue_state
# 0  The West Hartford Meeting & Conferen...          CT

# %%
df0.columns
# Out:
# Index(['body_length', 'channels', 'country', 'currency', 'delivery_method',
#        'description', 'email_domain', 'event_created', 'event_end',
#        'event_published', 'event_start', 'fb_published', 'has_analytics',
#        'has_header', 'has_logo', 'listed', 'name', 'name_length', 'object_id',
#        'org_desc', 'org_facebook', 'org_name', 'org_twitter', 'payee_name',
#        'payout_type', 'previous_payouts', 'sale_duration', 'sequence_number',
#        'show_map', 'ticket_types', 'user_age', 'user_created', 'user_type',
#        'venue_address', 'venue_country', 'venue_latitude', 'venue_longitude',
#        'venue_name', 'venue_state'],
#       dtype='object')

# %%
df['payout_type'] == 'ACH' *
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6         True
# 7         True
# 8         True
# 9         True
# 10       False
# 11        True
# 12       False
# 13        True
# 14       False
# 15       False
# 16       False
# 17       False
# 18        True
# 19        True
# 20        True
# 21       False
# 22       False
# 23       False
# 24       False
# 25        True
# 26        True
# 27       False
# 28        True
# 29        True
#          ...
# 14307     True
# 14308     True
# 14309     True
# 14310     True
# 14311    False
# 14312    False
# 14313     True
# 14314     True
# 14315     True
# 14316     True
# 14317     True
# 14318    False
# 14319    False
# 14320     True
# 14321     True
# 14322     True
# 14323     True
# 14324     True
# 14325    False
# 14326     True
# 14327    False
# 14328     True
# 14329     True
# 14330    False
# 14331    False
# 14332    False
# 14333    False
# 14334     True
# 14335     True
# 14336     True
# Name: payout_type, Length: 14337, dtype: bool

# %%
import requests
url = 'http://galvanize-case-study-on-fraud.herokuapp.com/data_point'

response = requests.get(url)
raw_data = response.json()

# %%
raw_data
# Out:
# {'approx_payout_date': 1376697600,
#  'body_length': 1105,
#  'channels': 11,
#  'country': 'AU',
#  'currency': 'AUD',
#  'delivery_method': 0.0,
#  'description': '<p>Come and join us for an evening of fun and learning !</p>\r\n<p>Francois Fourie, Jonathan Esling and Loic Le Guilly will lead this introductory photographic workshop to aurora and night sky photography.</p>\r\n<p>The program for the evening:</p>\r\n<ul>\r\n<li>equipment (camera, lenses, tripod, accessories, etc.)</li>\r\n<li>camera and lens settings</li>\r\n<li>introduction to startrail photography</li>\r\n<li>introduction to timelapse photography</li>\r\n<li>photo shoot (we will go near the Signal Station to practice)</li>\r\n<li>post-processing (in particular Lightroom but the principles apply to any software)</li>\r\n</ul>\r\n<p>The workshop will be aimed at people new or starting night sky photography. We will expect people to have a DSLR and a tripod (no point and shoot cameras please).</p>\r\n<p>Finger food included. Drinks and more food available for purchase from the restaurant (licenced).</p>\r\n<p>There are 2 workshops, one on Saturday 10 August and one on Sunday 11 August.<br />Your ticket gives you access to one or the other (not both).<br />Each workshop starts at 5pm and finishes at about 8pm.</p>',
#  'email_domain': 'ultimedia.com.au',
#  'event_created': 1372671476,
#  'event_end': 1376265600,
#  'event_published': 1372673825.0,
#  'event_start': 1376179200,
#  'fb_published': 0,
#  'gts': 2487.03,
#  'has_analytics': 0,
#  'has_header': None,
#  'has_logo': 1,
#  'listed': 'y',
#  'name': 'Aurora and night sky photography workshop in Hobart, Tasmania',
#  'name_length': 61,
#  'num_order': 48,
#  'num_payouts': 0,
#  'object_id': 7272837,
#  'org_desc': '<p>Loic Le Guilly is a professional photographer based in Hobart.</p>\r\n<p><a href="http://www.hobartphotographertasmania.com.au" target="_blank">www.hobartphotographertasmania.com.au</a></p>',
#  'org_facebook': 24.0,
#  'org_name': 'Loic Le Guilly',
#  'org_twitter': 0.0,
#  'payee_name': '',
#  'payout_type': 'ACH',
#  'previous_payouts': [{'address': '',
#    'amount': 2484.9,
#    'country': 'AU',
#    'created': '2013-08-16 03:13:13',
#    'event': 7272837,
#    'name': '',
#    'state': '',
#    'uid': 48481914,
#    'zip_code': ''},
#   {'address': '',
#    'amount': 1355.4,
#    'country': 'AU',
#    'created': '2013-08-22 03:15:02',
#    'event': 7369449,
#    'name': '',
#    'state': '',
#    'uid': 48481914,
#    'zip_code': ''}],
#  'sale_duration': 40.0,
#  'sale_duration2': 40,
#  'show_map': 1,
#  'ticket_types': [{'availability': 1,
#    'cost': 40.73,
#    'event_id': 7272837,
#    'quantity_sold': 25,
#    'quantity_total': 25},
#   {'availability': 1,
#    'cost': 40.73,
#    'event_id': 7272837,
#    'quantity_sold': 30,
#    'quantity_total': 30}],
#  'user_age': 195,
#  'user_created': 1355878966,
#  'user_type': 4,
#  'venue_address': '700 Nelson Rd',
#  'venue_country': 'AU',
#  'venue_latitude': -42.924468,
#  'venue_longitude': 147.344052,
#  'venue_name': 'The Signal Station Restaurant',
#  'venue_state': 'TAS'}

# %%
response = requests.get(url)
raw_data = response.json()
